# %% [markdown]
# Get all devices using emulator

# %%
import pypylon.pylon as py
import os

# %%
tlf = py.TlFactory.GetInstance()
devices = tlf.EnumerateDevices()
devices
# Out:
# ()

# %%
os.environ["PYLON_CAMEMU"] = "1"

# %%
tlf = py.TlFactory.GetInstance()
devices = tlf.EnumerateDevices()
devices
# Out:
# (<pypylon.pylon.DeviceInfo; proxy of <Swig Object of type 'Pylon::CDeviceInfo *' at 0x0000014758E3C300> >,)

# %%
os.environ["PYLON_CAMEMU"] = "3"

# %%
tlf = py.TlFactory.GetInstance()
devices = tlf.EnumerateDevices()
devices
# Out:
# (<pypylon.pylon.DeviceInfo; proxy of <Swig Object of type 'Pylon::CDeviceInfo *' at 0x0000014758F9DB90> >,
#  <pypylon.pylon.DeviceInfo; proxy of <Swig Object of type 'Pylon::CDeviceInfo *' at 0x00000147590E0ED0> >,
#  <pypylon.pylon.DeviceInfo; proxy of <Swig Object of type 'Pylon::CDeviceInfo *' at 0x00000147590E18C0> >)

# %%
os.environ["PYLON_CAMEMU"] = "1"

# %%
tlf = py.TlFactory.GetInstance()
devices = tlf.EnumerateDevices()
devices
# Out:
# (<pypylon.pylon.DeviceInfo; proxy of <Swig Object of type 'Pylon::CDeviceInfo *' at 0x0000014731F3FF90> >,)

# %%
device = devices[0]
device.GetFullName()
# Out:
# 'Emulation (0815-0000)'

# %%
device.GetModelName()
# Out:
# 'Emulation'

# %%
device.GetUsbDriverType()
# Out:
# 'N/A'
