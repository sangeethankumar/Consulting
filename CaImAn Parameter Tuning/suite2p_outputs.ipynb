# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ops = np.load('data/suite2p/plane0/ops.npy', allow_pickle=True)
ops
# Out:
# array({'suite2p_version': '0.14.4', 'look_one_level_down': 0.0, 'fast_disk': 'C:/Users/sangeetha/Tract/Consulting/CaImAn Parameter Tuning/data', 'delete_bin': False, 'mesoscan': False, 'bruker': False, 'bruker_bidirectional': False, 'h5py': [], 'h5py_key': 'data', 'nwb_file': '', 'nwb_driver': '', 'nwb_series': '', 'save_path0': 'C:/Users/sangeetha/Tract/Consulting/CaImAn Parameter Tuning/data', 'save_folder': 'suite2p', 'subfolders': [], 'move_bin': False, 'nplanes': 1, 'nchannels': 1, 'functional_chan': 1, 'tau': 1.0, 'fs': 10.0, 'force_sktiff': False, 'frames_include': -1, 'multiplane_parallel': 0.0, 'ignore_flyback': [], 'preclassify': 0.0, 'save_mat': False, 'save_NWB': 0.0, 'combined': 1.0, 'aspect': np.float64(1.0), 'do_bidiphase': False, 'bidiphase': 0.0, 'bidi_corrected': False, 'do_registration': 1, 'two_step_registration': 0.0, 'keep_movie_raw': False, 'nimg_init': 300, 'batch_size': 500, 'maxregshift': 0.1, 'align_by_chan': 1, 'reg_tif': False, 'reg_tif_chan2': False, 'su
# ...

# %% [markdown]
# decay_time: C-0.4, s2p-(0.7 GCaMP6f, 1.0 GCaMP6m, 1.25-1.5 GCaMP6s)
# fs: C-?, s2p:10
# rf: C-3-4 times larger than expected neuron size
#
# Caiman
# gSig: Expected half-size of neurons in pixels [rows X columns]
# gSiz: odd size,
# If cells are 12px across, gSig [3,3] and gSiz [13, 13]
