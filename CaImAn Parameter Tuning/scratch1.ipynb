# %%
import caiman as cm
# Out:
# WARNING:tensorflow:From c:\Users\sangeetha\miniforge3\envs\c_github\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mv = cm.load('data/multi_cell.tif')

# %%
mv.shape
# Out:
# (2000, 60, 80)

# %%
plt.imshow(mv[0]);

# %%
plt.imshow(np.mean(mv, axis=0))

# %%
plt.imshow(np.median(mv, axis=0))

# %%
plt.imshow(np.max(mv, axis=0))

# %%
plt.imshow(np.std(mv, axis=0))

# %%
corr_mv = cm.local_correlations(mv, swap_dim=False)
corr_mv.shape
# Out:
# (60, 80)

# %%
plt.imshow(corr_mv)
